# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('dataset/train.csv')

# %%
data.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#   Express Shipment Installation Included Transport Fragile  \
# ...

# %%
data['Remote Location'] = data['Remote Location'].replace({'No': 0, 'Yes': 1})
data['International'] = data['International'].replace({'No': 0, 'Yes': 1})
data['Fragile'] = data['Fragile'].replace({'No': 0, 'Yes': 1})
data['Installation Included'] = data['Installation Included'].replace({'No': 0, 'Yes': 1})
data['Express Shipment'] = data['Express Shipment'].replace({'No': 0, 'Yes': 1})

# %%
data.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price  International  \
# 0  4128.0      Brass               13.91                16.27              1
# 1    61.0      Brass                6.83                15.00              0
# 2   237.0       Clay                4.96                21.18              0
# 3     NaN  Aluminium                5.81                16.31              0
# 4   324.0  Aluminium                3.18                11.94              1
#
# ...

# %%
data = data.drop('Artist Name',axis=1)

# %%
data.head()
# Out:
#             Customer Id  Artist Reputation  Height  Width  Weight   Material  \
# 0  fffe3900350033003300               0.26    17.0    6.0  4128.0      Brass
# 1  fffe3800330031003900               0.28     3.0    3.0    61.0      Brass
# 2  fffe3600370035003100               0.07     8.0    5.0   237.0       Clay
# 3      fffe350031003300               0.12     9.0    NaN     NaN  Aluminium
# 4  fffe3900320038003400               0.15    17.0    6.0   324.0  Aluminium
#
#    Price Of Sculpture  Base Shipping Price  International  Express Shipment  \
# 0               13.91                16.27              1                 1
# 1                6.83                15.00              0                 0
# 2                4.96                21.18              0                 0
# 3                5.81                16.31              0                 0
# 4                3.18                11.94              1                 1
#
# ...

# %%
data = data.drop('Customer Id',axis=1)

# %%
data = data.drop('Customer Location',axis=1)

# %%
data.head()
# Out:
#    Artist Reputation  Height  Width  Weight   Material  Price Of Sculpture  \
# 0               0.26    17.0    6.0  4128.0      Brass               13.91
# 1               0.28     3.0    3.0    61.0      Brass                6.83
# 2               0.07     8.0    5.0   237.0       Clay                4.96
# 3               0.12     9.0    NaN     NaN  Aluminium                5.81
# 4               0.15    17.0    6.0   324.0  Aluminium                3.18
#
#    Base Shipping Price  International  Express Shipment  \
# 0                16.27              1                 1
# 1                15.00              0                 0
# 2                21.18              0                 0
# 3                16.31              0                 0
# 4                11.94              1                 1
#
#    Installation Included Transport  Fragile Customer Information  \
# 0                      0   Airways        0        Working Class
# ...

# %%
data['Material'].unique()
# Out:
# array(['Brass', 'Clay', 'Aluminium', 'Wood', 'Marble', 'Bronze', 'Stone',
#        nan], dtype=object)

# %%
data.describe()
# Out:
#        Artist Reputation       Height        Width        Weight  \
# count        5750.000000  6125.000000  5916.000000  5.913000e+03
# mean            0.461850    21.766204     9.617647  4.006948e+05
# std             0.265781    11.968192     5.417000  2.678081e+06
# min             0.000000     3.000000     2.000000  3.000000e+00
# 25%             0.240000    12.000000     6.000000  5.030000e+02
# 50%             0.450000    20.000000     8.000000  3.102000e+03
# 75%             0.680000    30.000000    12.000000  3.645600e+04
# max             1.000000    73.000000    50.000000  1.179279e+08
#
#        Price Of Sculpture  Base Shipping Price  International  \
# count          6500.00000          6500.000000    6500.000000
# mean           1192.42009            37.407174       0.339385
# std            8819.61675            26.873519       0.473537
# min               3.00000            10.000000       0.000000
# 25%               5.23000            16.700000       0.000000
# ...

# %%
data['Material'].unique()
# Out:
# array(['Brass', 'Clay', 'Aluminium', 'Wood', 'Marble', 'Bronze', 'Stone',
#        nan], dtype=object)

# %%
type(pd.get_dummies(data['Material']))
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    Artist Reputation  Height  Width  Weight   Material  Price Of Sculpture  \
# 0               0.26    17.0    6.0  4128.0      Brass               13.91
# 1               0.28     3.0    3.0    61.0      Brass                6.83
# 2               0.07     8.0    5.0   237.0       Clay                4.96
# 3               0.12     9.0    NaN     NaN  Aluminium                5.81
# 4               0.15    17.0    6.0   324.0  Aluminium                3.18
#
#    Base Shipping Price  International  Express Shipment  \
# 0                16.27              1                 1
# 1                15.00              0                 0
# 2                21.18              0                 0
# 3                16.31              0                 0
# 4                11.94              1                 1
#
#    Installation Included Transport  Fragile Customer Information  \
# 0                      0   Airways        0        Working Class
# ...

# %%
int((data['Scheduled Date'][234])[3:5])-int((data['Delivery Date'][234])[3:5])
# Out:
# -4
